# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url="https://www.airbnb.co.in/s/New-Delhi--India/homes?adults=1&place_id=ChIJLbZ-NFv9DDkRzk0gTkm3wlI&refinement_paths%5B%5D=%2Fhomes&tab_id=home_tab&query=New%20Delhi%2C%20India&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2023-11-01&monthly_length=3&price_filter_input_type=0&price_filter_num_nights=5&channel=EXPLORE&search_type=unknown&federated_search_session_id=55840e05-e0ff-4de8-be8b-185ae4e2c6c8&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0IjowLCJ2ZXJzaW9uIjoxfQ%3D%3D"

# %%
r=requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(r.text,"lxml")
soup
# Out:
# <!DOCTYPE html>
# <html data-hyperloop-version="1" data-is-hyperloop="true" dir="ltr" lang="en-IN"><head><meta charset="utf-8"/><meta content="en-IN" name="locale"/><meta content="notranslate" name="google"/><meta content="authenticity_token" id="csrf-param-meta-tag" name="csrf-param"/><meta content="" id="csrf-token-meta-tag" name="csrf-token"/><meta content="" id="english-canonical-url"/><meta content="on" name="twitter:widgets:csp"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="Airbnb" name="application-name"/><meta content="Airbnb" name="apple-mobile-web-app-title"/><meta content="#ffffff" name="theme-color"/><meta content="#ffffff" name="msapplication-navbutton-color"/><meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/><meta content="/?utm_source=homescreen" name="msapplication-starturl"/><script>(function() {
#   // pg_pixel is no-op now.
# ...

# %%
np=soup.find("a",class_="l1ovpqvx c1ytbx3a dir dir-ltr").get("href")
np="https://www.airbnb.co.in"+np
np
# Out:
# 'https://www.airbnb.co.in/s/New-Delhi--India/homes?adults=1&place_id=ChIJLbZ-NFv9DDkRzk0gTkm3wlI&refinement_paths%5B%5D=%2Fhomes&tab_id=home_tab&query=New%20Delhi%2C%20India&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2023-11-01&monthly_length=3&price_filter_input_type=0&price_filter_num_nights=5&channel=EXPLORE&federated_search_session_id=b35fb369-ca3e-447e-a72b-74d58fe31d21&search_type=unknown&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxOCwidmVyc2lvbiI6MX0%3D'

# %%
while True:
    np=soup.find("a",class_="l1ovpqvx c1ytbx3a dir dir-ltr").get("href")
    np="https://www.airbnb.co.in"+np
    print(np)
    url=np
    r=requests.get(url)
    soup=BeautifulSoup(r.text,"lxml")
# Out:
# https://www.airbnb.co.in/s/New-Delhi--India/homes?adults=1&place_id=ChIJLbZ-NFv9DDkRzk0gTkm3wlI&refinement_paths%5B%5D=%2Fhomes&tab_id=home_tab&query=New%20Delhi%2C%20India&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2023-11-01&monthly_length=3&price_filter_input_type=0&price_filter_num_nights=5&channel=EXPLORE&federated_search_session_id=dd315c07-2ac6-4fa0-a765-2d8abf834bd9&search_type=unknown&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0IjoxOCwidmVyc2lvbiI6MX0%3D
# ...

# %%
Names=[]
Prices=[]
Descs=[]
Reviews=[]
np=soup.find("a",class_="l1ovpqvx c1ytbx3a dir dir-ltr").get("href")
np="https://www.airbnb.co.in"+np
print(np)
url=np
r=requests.get(url)
soup=BeautifulSoup(r.text,"lxml")
# Out:
# https://www.airbnb.co.in/s/New-Delhi--India/homes?adults=1&place_id=ChIJLbZ-NFv9DDkRzk0gTkm3wlI&refinement_paths%5B%5D=%2Fhomes&tab_id=home_tab&query=New%20Delhi%2C%20India&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2023-11-01&monthly_length=3&price_filter_input_type=0&price_filter_num_nights=5&channel=EXPLORE&search_type=unknown&federated_search_session_id=b35fb369-ca3e-447e-a72b-74d58fe31d21&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MiwiaXRlbXNfb2Zmc2V0Ijo3MiwidmVyc2lvbiI6MX0%3D

# %%
Names=[]
names=soup.find_all("div",class_="t1jojoys dir dir-ltr")
print(names)
for i in names:
    Names.append(i.text)
Names
# Out:
# [<div class="t1jojoys dir dir-ltr" data-testid="listing-card-title" id="title_28763654">Flat in New Delhi</div>, <div class="t1jojoys dir dir-ltr" data-testid="listing-card-title" id="title_1001500084994900246">Home in New Delhi</div>, <div class="t1jojoys dir dir-ltr" data-testid="listing-card-title" id="title_828712888918632502">Room in New Delhi</div>, <div class="t1jojoys dir dir-ltr" data-testid="listing-card-title" id="title_491208">Flat in New Delhi</div>, <div class="t1jojoys dir dir-ltr" data-testid="listing-card-title" id="title_21237760">Shared room in New Delhi</div>, <div class="t1jojoys dir dir-ltr" data-testid="listing-card-title" id="title_1000706845935077758">Flat in Noida</div>, <div class="t1jojoys dir dir-ltr" data-testid="listing-card-title" id="title_41223677">Home in New Delhi</div>, <div class="t1jojoys dir dir-ltr" data-testid="listing-card-title" id="title_42882323">Room in New Delhi</div>, <div class="t1jojoys dir dir-ltr" data-testid="listing-card-title" i
# ...

# %%
Price=[]
prices=soup.find_all("span",class_="a8jt5op dir dir-ltr")
print(prices)
for i in prices:
    Price.append(i.text)
Price
Prices=[]
for i in Price:
    i=str(i)
    if i[0] == '₹':
        Prices.append(i)
Prices
# Out:
# [<span class="a8jt5op dir dir-ltr" id="littleSearchLabel">Start your search</span>, <span class="a8jt5op dir dir-ltr">Location</span>, <span class="a8jt5op dir dir-ltr">Check in / Check out</span>, <span class="a8jt5op dir dir-ltr">Guests</span>, <span class="a8jt5op dir dir-ltr">I’m flexible</span>, <span class="a8jt5op dir dir-ltr">Europe</span>, <span class="a8jt5op dir dir-ltr">United Kingdom</span>, <span class="a8jt5op dir dir-ltr">Southeast Asia</span>, <span class="a8jt5op dir dir-ltr">Canada</span>, <span class="a8jt5op dir dir-ltr">United States</span>, <span class="a8jt5op dir dir-ltr">Search results</span>, <span class="a8jt5op dir dir-ltr">₹7,196 per night</span>, <span class="a8jt5op dir dir-ltr">₹7,353 per night</span>, <span class="a8jt5op dir dir-ltr">, </span>, <span class="a8jt5op dir dir-ltr">₹2,010 per night</span>, <span class="a8jt5op dir dir-ltr">₹4,365 per night</span>, <span class="a8jt5op dir dir-ltr">₹648 per night</span>, <span class="a8jt5op dir dir-ltr"
# ...

# %%
Descs=[]
descr=soup.find_all("span",class_="t6mzqp7 dir dir-ltr")
print(descr)
for i in descr:
    Descs.append(i.text)
Descs
# Out:
# [<span class="t6mzqp7 dir dir-ltr" data-testid="listing-card-name" lang="en">The Royal Heritage @hkv</span>, <span class="t6mzqp7 dir dir-ltr" data-testid="listing-card-name" lang="en">Penthouse overlooking lake,Jacuzzi+bar+projector.</span>, <span class="t6mzqp7 dir dir-ltr" data-testid="listing-card-name" lang="en">Ficus - a cosy terrace room with open space</span>, <span class="t6mzqp7 dir dir-ltr" data-testid="listing-card-name" lang="en">Heritage Apt 1@Hauz Khas Village</span>, <span class="t6mzqp7 dir dir-ltr" data-testid="listing-card-name" lang="en-IN">FriendsIndia</span>, <span class="t6mzqp7 dir dir-ltr" data-testid="listing-card-name" lang="en">The WhiteRock - 41st Floor River view</span>, <span class="t6mzqp7 dir dir-ltr" data-testid="listing-card-name" lang="en">JACUZZI, STUNNING1BR ,TERRACE, LOCATION ❤️🌈🦮</span>, <span class="t6mzqp7 dir dir-ltr" data-testid="listing-card-name" lang="en">Couple-Friendly with  private entrance in S. Delhi</span>, <span class="t6mzqp7 dir
# ...

# %%
Reviews=[]
review=soup.find_all("span",class_="r1dxllyb dir dir-ltr")
print(review)
X=[]
for i in review:
    Reviews.append(i.text)
Reviews
# Out:
# [<span aria-hidden="true" class="r1dxllyb dir dir-ltr">4.76 (240)</span>, <span aria-hidden="true" class="r1dxllyb dir dir-ltr">New</span>, <span aria-hidden="true" class="r1dxllyb dir dir-ltr">4.96 (49)</span>, <span aria-hidden="true" class="r1dxllyb dir dir-ltr">4.81 (518)</span>, <span aria-hidden="true" class="r1dxllyb dir dir-ltr">4.47 (30)</span>, <span aria-hidden="true" class="r1dxllyb dir dir-ltr">4.75 (4)</span>, <span aria-hidden="true" class="r1dxllyb dir dir-ltr">4.93 (246)</span>, <span aria-hidden="true" class="r1dxllyb dir dir-ltr">4.76 (180)</span>, <span aria-hidden="true" class="r1dxllyb dir dir-ltr">4.96 (45)</span>, <span aria-hidden="true" class="r1dxllyb dir dir-ltr">4.87 (77)</span>, <span aria-hidden="true" class="r1dxllyb dir dir-ltr">4.88 (198)</span>, <span aria-hidden="true" class="r1dxllyb dir dir-ltr">4.9 (145)</span>, <span aria-hidden="true" class="r1dxllyb dir dir-ltr">4.8 (202)</span>, <span aria-hidden="true" class="r1dxllyb dir dir-ltr">4.49 (146
# ...

# %%
import pandas as pd

# %%
Descs
# Out:
# ['The Royal Heritage @hkv',
#  'Penthouse overlooking lake,Jacuzzi+bar+projector.',
#  'Ficus - a cosy terrace room with open space',
#  'Heritage Apt 1@Hauz Khas Village',
#  'FriendsIndia',
#  'The WhiteRock - 41st Floor River view',
#  'JACUZZI, STUNNING1BR ,TERRACE, LOCATION ❤️🌈🦮',
#  'Couple-Friendly with  private entrance in S. Delhi',
#  'Modern 2 Bedroom Apartment for Perfect Stay',
#  'Space',
#  'South Delhi Home with Beautiful Terrace: 1',
#  'Ekal Kamra@Haveli Heritage room in Green Park',
#  '5Star Independent Studio in South Delhi Nblock GK1',
#  'Vintage Blue-A Chic Private room in Shared Space',
#  'Vasant Kunj - A ROOM WITH A  VIEW ! and WHOLE ROOF',
#  'Quaint and cosy room in south delhi',
#  'Studio apartment with common terrace',
#  'The Terrace Penthouse, \nexclusive Lutyens Delhi']

# %%
Names
# Out:
# ['Flat in New Delhi',
#  'Home in New Delhi',
#  'Room in New Delhi',
#  'Flat in New Delhi',
#  'Shared room in New Delhi',
#  'Flat in Noida',
#  'Home in New Delhi',
#  'Room in New Delhi',
#  'Flat in New Delhi',
#  'Room in Delhi',
#  'Room in New Delhi',
#  'Place to stay in New Delhi',
#  'Flat in New Delhi',
#  'Room in New Delhi',
#  'Guest house in New Delhi',
#  'Room in New Delhi',
#  'Holiday home in New Delhi',
#  'Home in New Delhi']

# %%
Prices
# Out:
# ['₹7,196 per night',
#  '₹7,353 per night',
#  '₹2,010 per night',
#  '₹4,365 per night',
#  '₹648 per night',
#  '₹4,775 per night',
#  '₹8,743 per night, originally ₹10,047',
#  '₹2,055 per night',
#  '₹3,432 per night',
#  '₹1,141 per night',
#  '₹3,652 per night',
#  '₹5,478 per night',
#  '₹5,138 per night',
#  '₹2,490 per night',
#  '₹1,130 per night',
#  '₹1,652 per night',
#  '₹3,766 per night',
#  '₹9,347 per night']

# %%
Reviews
# Out:
# ['4.76 (240)',
#  'New',
#  '4.96 (49)',
#  '4.81 (518)',
#  '4.47 (30)',
#  '4.75 (4)',
#  '4.93 (246)',
#  '4.76 (180)',
#  '4.96 (45)',
#  '4.87 (77)',
#  '4.88 (198)',
#  '4.9 (145)',
#  '4.8 (202)',
#  '4.49 (146)',
#  '4.78 (63)',
#  '4.85 (83)',
#  '4.61 (110)',
#  '4.99 (182)']

# %%
df=pd.DataFrame({"Name":Names,"Description":Descs,"Price":Prices,"Review":Reviews})

# %%
df
# Out:
#                           Name  \
# 0            Flat in New Delhi
# 1            Home in New Delhi
# 2            Room in New Delhi
# 3            Flat in New Delhi
# 4     Shared room in New Delhi
# 5                Flat in Noida
# 6            Home in New Delhi
# 7            Room in New Delhi
# 8            Flat in New Delhi
# 9                Room in Delhi
# 10           Room in New Delhi
# 11  Place to stay in New Delhi
# 12           Flat in New Delhi
# 13           Room in New Delhi
# 14    Guest house in New Delhi
# 15           Room in New Delhi
# 16   Holiday home in New Delhi
# 17           Home in New Delhi
#
#                                           Description  \
# 0                             The Royal Heritage @hkv
# 1   Penthouse overlooking lake,Jacuzzi+bar+projector.
# 2         Ficus - a cosy terrace room with open space
# 3                    Heritage Apt 1@Hauz Khas Village
# 4                                        FriendsIndia
# ...

# %%
Names=[]
Prices=[]
Descs=[]
Reviews=[]
for i in range(1,14):
    np=soup.find("a",class_="l1ovpqvx c1ytbx3a dir dir-ltr").get("href")
    np="https://www.airbnb.co.in"+np
    url=np
    r=requests.get(url)
    soup=BeautifulSoup(r.text,"lxml")
    
    names=soup.find_all("div",class_="t1jojoys dir dir-ltr")
    for i in names:
        Names.append(i.text)
        
    Price=[]
    prices=soup.find_all("span",class_="a8jt5op dir dir-ltr")
    for i in prices:
        Price.append(i.text)
    for i in Price:
        i=str(i)
        if i[0] == '₹':
            Prices.append(i)

    descr=soup.find_all("span",class_="t6mzqp7 dir dir-ltr")
    for i in descr:
        Descs.append(i.text)

#   review=soup.find_all("span",class_="r1dxllyb dir dir-ltr")
#    for i in review:
#        Reviews.append(i.text)

# %%
df=pd.DataFrame({"Name":Names,"Description":Descs,"Price":Prices})
df.set_index("Name",inplace=True)
df.to_csv("Airbnb_NewDelhi.csv")

# %%
df
# Out:
#                                                                        Description  \
# Name
# Flat in New Delhi                                       Apartment for day-dreamers
# Hotel room in New Delhi              A Bright & Cozy Modern Room in a Shared Space
# Room in New Delhi                                 StrawberryFields:double bed, gk2
# Room in New Delhi                Room 1,budget double bed Def Col ,couple friendly
# Room in New Delhi                Sunny, Airy, Huge Room & Balcony - 1 min frm M...
# ...                                                                            ...
# Tiny home in Greater Kailash II  Bella's Roost - 1 bedroom apartment in South D...
# Room in Mahrauli                                 Pink Bliss: Cozy Retreat in Saket
# Flat in Hauz Khas                                       Harphool Nivas - Penthouse
# Room in Naraina                                        A clean and simple bedroom.
# ...
